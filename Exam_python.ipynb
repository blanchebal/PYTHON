# %% [markdown]
# # Exam PYTHON
# ## BALOGOUN H. Inès Blanche

# %% [markdown]
# ### Exercice 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.arange(0,11,1)
y=x**5

# %%
plt.plot(x,y)
plt.show()

# %%
x=(0,1)
y=(0,1)
plt.plot(x,y)
plt.grid(color="r")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %% [markdown]
# ### Exercice 2

# %%
def curve(start,stop,nbr_points=5432):
    x=np.arange(start,stop)
    y=x**5
    plt.plot(x,y)
    plt.show()
